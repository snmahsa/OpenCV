# %%
#import library
import cv2
import Core.utils as utl

# %%
image = utl.upload_of_local()
print(image)
# Out:
# No file selected
# None

# %%
pen_img = utl.read_img_from_file()

# %%
utl.show_img_plot(pen_img)

# %%
hsv_image = utl.convert_to_hsv(pen_img)
utl.show_img_plot(hsv_image)

# %%
stack = utl.get_stack(pen_img, hsv_image)
utl.show_img_plot(stack)

# %%
r = utl.ratio_resize_img(stack, 10,8)
utl.show_img_plot(r)

# %%
x = utl.extraction_color_in_img(pen_img,(60,0,0),(180,255,255))
utl.show_img_plot(x)

# %%
hsv = utl.convert_to_hsv(pen_img)
mask = utl.creat_mask(hsv,(60,0,0),(180,255,255))
utl.show_img_plot(mask)

# %%
erois = utl.eriosion(mask,5)
utl.show_img_plot(erois)

# %%
cap = cv2.VideoCapture('/home/mahsa/Desktop/ENV/DIP_ENV/opencv/Video/clip.mp4')

# %%
utl.read_frames(cap)

# %%
utl.upload_Video_of_local()

# %%
cap2 = utl.read_video_from_folder()

# %%
utl.read_frames(cap2)
